# %% [markdown]
# # BigQuery basics
#
# [BigQuery](https://cloud.google.com/bigquery/docs/) is a petabyte-scale analytics data warehouse that you can use to run SQL queries over vast amounts of data in near realtime. This page shows you how to get started with the Google BigQuery API using the Python client library.

# %% [markdown]
# ## Import the libraries used in this tutorial

# %%
from google.cloud import bigquery
import pandas as pd
pd.set_option('display.max_columns', 500)

# %% [markdown]
# ## Initialize a client
#
# To use the BigQuery Python client library, start by initializing a client. The BigQuery client is used to send and receive messages from the BigQuery API.
#
# ### Client project
# The `bigquery.Client` object uses your default project. Alternatively, you can specify a project in the `Client` constructor. For more information about how the default project is determined, see the [google-auth documentation](https://google-auth.readthedocs.io/en/latest/reference/google.auth.html).
#
#
# ### Client location
# Locations are required for certain BigQuery operations such as creating a dataset. If a location is provided to the client when it is initialized, it will be the default location for jobs, datasets, and tables.
#
# Run the following to create a client with your default project:

# %%
client = bigquery.Client(location="EU")
print("Client creating using default project: {}".format(client.project))
# Out:
# Client creating using default project: pacific-destiny-243512

# %% [markdown]
# To explicitly specify a project when constructing the client, set the `project` parameter:

# %%
# client = bigquery.Client(location="US", project="your-project-id")

# %% [markdown]
# ## Run a query on a public dataset
#
# The following example queries the BigQuery `usa_names` public dataset to find the 10 most popular names. `usa_names` is a Social Security Administration dataset that contains all names from Social Security card applications for births that occurred in the United States after 1879.
#
# Use the [Client.query](https://googleapis.github.io/google-cloud-python/latest/bigquery/generated/google.cloud.bigquery.client.Client.html#google.cloud.bigquery.client.Client.query) method to run the query, and the [QueryJob.to_dataframe](https://googleapis.github.io/google-cloud-python/latest/bigquery/generated/google.cloud.bigquery.job.QueryJob.html#google.cloud.bigquery.job.QueryJob.to_dataframe) method to return the results as a pandas [`DataFrame`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html).

# %%
query = """
    SELECT
  wx.date,
  wx.value/10.0 AS prcp
FROM
  `bigquery-public-data.ghcn_d.ghcnd_2015` AS wx
WHERE
  id = 'UKM00003772'
  AND qflag IS NULL
  AND element = 'PRCP'
ORDER BY
  wx.date
"""
query_job = client.query(
    query,
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
)  # API request - starts the query

df = query_job.to_dataframe()
df
# Out:
#            date  prcp
# 0    2015-01-01   0.3
# 1    2015-01-02   1.0
# 2    2015-01-03   3.8
# 3    2015-01-04   7.1
# 4    2015-01-05   0.0
# 5    2015-01-06   0.3
# 6    2015-01-07   1.0
# 7    2015-01-08   1.0
# 8    2015-01-09  12.4
# 9    2015-01-10   0.0
# 10   2015-01-11   0.8
# 11   2015-01-12   0.5
# 12   2015-01-13  13.7
# 13   2015-01-14   2.0
# 14   2015-01-15   7.9
# 15   2015-01-16   0.5
# 16   2015-01-17   0.3
# 17   2015-01-18   1.0
# 18   2015-01-19   0.3
# 19   2015-01-20   0.0
# 20   2015-01-21   0.5
# 21   2015-01-22   0.3
# 22   2015-01-23   0.0
# 23   2015-01-24   2.8
# 24   2015-01-25   0.0
# 25   2015-01-26   0.3
# 26   2015-01-27   0.3
# 27   2015-01-28   0.0
# 28   2015-01-29   1.0
# 29   2015-01-30   1.5
# ..          ...   ...
# 332  2015-12-02   0.0
# 333  2015-12-03   0.0
# 334  2015-12-04   2.3
# 335  2015-12-05   0.0
# 336  2015-12-06   0.0
# 337  2015-12-07   0.3
# 338  2015-12-08   1.5
# 339  2015-12-09   1.0
# 340  2015-12-10   0.0
# 341  2015-12-11   4.3
# 342  2015-12-12   0.3
# 343  2015-12-13   1.3
# 344  2015-12-14   0.5
# 345  2015-12-15   0.3
# 346  2015-12-16   5.1
# 347  2015-12-17   0.0
# 348  2015-12-18   0.0
# 349  2015-12-19   0.0
# 350  2015-12-20   0.0
# 351  2015-12-21   1.5
# 352  2015-12-22   2.0
# 353  2015-12-23   4.3
# 354  2015-12-24   0.0
# 355  2015-12-25   2.0
# 356  2015-12-26   1.8
# 357  2015-12-27   0.0
# 358  2015-12-28   0.3
# 359  2015-12-29   1.3
# 360  2015-12-30   0.3
# 361  2015-12-31   7.1
#
# [362 rows x 2 columns]

# %%
query = """
SELECT
  *
FROM
  `bigquery-public-data.ghcn_d.ghcnd_2015` AS wx
WHERE
  date > "2015-06-23"
ORDER BY
  wx.date
LIMIT
  10
"""
query_job = client.query(
    query,
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
)  # API request - starts the query

df = query_job.to_dataframe()
df
# Out:
#             id        date element  value mflag qflag sflag  time
# 0  USC00419367  2015-06-24    PRCP    0.0  None  None     7  1000
# 1  USC00058429  2015-06-24    SNOW    0.0  None  None     7  None
# 2  USC00502015  2015-06-24    SNWD    0.0  None  None     7  2000
# 3  USC00262296  2015-06-24    SNOW    0.0  None  None     7  None
# 4  USC00044303  2015-06-24    PRCP    0.0  None  None     7  1500
# 5  USC00218419  2015-06-24    PRCP    0.0  None  None     7  1400
# 6  USC00107346  2015-06-24    PRCP    0.0  None  None     7  2000
# 7  USC00396669  2015-06-24    SNOW    0.0  None  None     7  None
# 8  USC00203744  2015-06-24    SNOW    0.0  None  None     7  None
# 9  USC00309049  2015-06-24    SNWD    0.0  None  None     7  2000

# %% [markdown]
# ## London Crime Data

# %%
query_crime = """
SELECT 
  *
FROM
  `bigquery-public-data.london_crime.crime_by_lsoa` AS lc
WHERE
  year = 2015
LIMIT 10

"""
query_job = client.query(
    query_crime,
    # Location must match that of the dataset(s) referenced in the query.
    location="EU",
)  # API request - starts the query
dfc = query_job.to_dataframe()
dfc
# Out:
#    lsoa_code         borough               major_category minor_category  \
# 0  E01000001  City of London  Violence Against the Person     Harassment
# 1  E01000005  City of London  Violence Against the Person     Harassment
# 2  E01032739  City of London  Violence Against the Person     Harassment
# 3  E01000005  City of London  Violence Against the Person     Harassment
# 4  E01032740  City of London  Violence Against the Person     Harassment
# 5  E01000001  City of London  Violence Against the Person     Harassment
# 6  E01000005  City of London           Theft and Handling    Other Theft
# 7  E01000005  City of London           Theft and Handling    Other Theft
# 8  E01000005  City of London           Theft and Handling    Other Theft
# 9  E01000002  City of London           Theft and Handling    Other Theft
#
#    value  year  month
# 0      0  2015      2
# 1      0  2015      7
# 2      1  2015      5
# 3      0  2015      8
# 4      0  2015     10
# 5      0  2015      8
# 6      2  2015     11
# 7      1  2015      6
# 8      1  2015      5
# 9      0  2015      9

# %% [markdown]
# #### Major Categories of Crime

# %%
query_crime = """
SELECT DISTINCT
  major_category
FROM
  `bigquery-public-data.london_crime.crime_by_lsoa` AS lc
WHERE
  year = 2015

"""
query_job = client.query(
    query_crime,
    # Location must match that of the dataset(s) referenced in the query.
    location="EU",
)  # API request - starts the query
dfc = query_job.to_dataframe()
dfc
# Out:
#                 major_category
# 0  Violence Against the Person
# 1           Theft and Handling
# 2                        Drugs
# 3    Other Notifiable Offences
# 4                      Robbery
# 5              Criminal Damage
# 6                     Burglary
# 7              Sexual Offences
# 8             Fraud or Forgery

# %% [markdown]
# ### Number of crimes by Major Category of crime

# %%
query_crime = """
SELECT 
  major_category, SUM(value)
FROM
  `bigquery-public-data.london_crime.crime_by_lsoa` AS lc
WHERE
  year = 2015
GROUP BY
  major_category

"""
query_job = client.query(
    query_crime,
    # Location must match that of the dataset(s) referenced in the query.
    location="EU",
)  # API request - starts the query
dfc = query_job.to_dataframe()
dfc
# Out:
#                 major_category     f0_
# 0  Violence Against the Person  218740
# 1           Theft and Handling  284022
# 2                        Drugs   39785
# 3    Other Notifiable Offences   14229
# 4                      Robbery   21383
# 5              Criminal Damage   62976
# 6                     Burglary   70489
# 7              Sexual Offences       0
# 8             Fraud or Forgery       0

# %% [markdown]
# ## London Brigade Fire Alarms

# %%
query_crime = """
SELECT 
  *
FROM
  `bigquery-public-data.london_fire_brigade.fire_brigade_service_calls` AS fire
WHERE
  incident_group = 'Fire' AND 
  cal_year = 2017
LIMIT
  10


"""
query_job = client.query(
    query_crime,
    # Location must match that of the dataset(s) referenced in the query.
    location="EU",
)  # API request - starts the query
dfc = query_job.to_dataframe()
dfc
# Out:
#    incident_number date_of_call  cal_year time_of_call  hour_of_call  \
# 0  040741-04042017   2017-04-04      2017     20:44:06            20
# 1  005509-13012017   2017-01-13      2017     19:49:12            19
# 2  052246-26042017   2017-04-26      2017     19:57:45            19
# 3  014805-04022017   2017-02-04      2017     18:57:47            18
# 4  012336-29012017   2017-01-29      2017     12:48:43            12
# 5  017339-10022017   2017-02-10      2017     20:49:49            20
# 6  013560-01022017   2017-02-01      2017     14:39:35            14
# 7  001299-03012017   2017-01-03      2017     19:27:40            19
# 8  005870-14012017   2017-01-14      2017     18:50:40            18
# 9  034166-21032017   2017-03-21      2017     19:57:54            19
#
#           timestamp_of_call incident_group stop_code_description  \
# 0 2017-04-04 20:44:06+00:00           Fire             Late Call
# 1 2017-01-13 19:49:12+00:00           Fire          Chimney Fire
# 2 2017-04-26 19:57:45+00:00           Fire          Chimney Fire
# 3 2017-02-04 18:57:47+00:00           Fire          Chimney Fire
# 4 2017-01-29 12:48:43+00:00           Fire          Chimney Fire
# 5 2017-02-10 20:49:49+00:00           Fire          Chimney Fire
# 6 2017-02-01 14:39:35+00:00           Fire          Chimney Fire
# 7 2017-01-03 19:27:40+00:00           Fire          Chimney Fire
# 8 2017-01-14 18:50:40+00:00           Fire          Chimney Fire
# 9 2017-03-21 19:57:54+00:00           Fire          Chimney Fire
#
#   special_service_type property_category  \
# 0                 None          Dwelling
# 1                 None          Dwelling
# 2                 None          Dwelling
# 3                 None          Dwelling
# 4                 None          Dwelling
# 5                 None   Non Residential
# 6                 None          Dwelling
# 7                 None          Dwelling
# 8                 None          Dwelling
# 9                 None   Non Residential
#
#                                        property_type  \
# 0  Purpose Built Flats/Maisonettes - Up to 3 stor...
# 1                          House - single occupancy
# 2                          House - single occupancy
# 3                          House - single occupancy
# 4                          House - single occupancy
# 5                                  Pub/wine bar/bar
# 6  Purpose Built Flats/Maisonettes - Up to 3 stor...
# 7                          House - single occupancy
# 8                          House - single occupancy
# 9                                  Pub/wine bar/bar
#
#            address_qualifier postcode_full postcode_district borough_code  \
# 0  Correct incident location          None               E11    E09000026
# 1       Within same building          None               BR6    E09000006
# 2  Correct incident location          None               CR0    E09000008
# 3  Correct incident location          None               N14    E09000010
# 4  Correct incident location          None              SE10    E09000011
# 5  Correct incident location       N15 3DA               N15    E09000014
# 6  Correct incident location          None               RM3    E09000016
# 7  Correct incident location          None               RM5    E09000016
# 8  Correct incident location          None               KT5    E09000021
# 9  Correct incident location      SE19 1QH              SE19    E09000022
#
#            borough_name           proper_case  ward_code  \
# 0             REDBRIDGE             Redbridge  E05000513
# 1               BROMLEY               Bromley  E05000110
# 2               CROYDON               Croydon  E05000157
# 3               ENFIELD               Enfield  E05000208
# 4             GREENWICH             Greenwich  E05000222
# 5              HARINGEY              Haringey  E05000282
# 6              HAVERING              Havering  E05000314
# 7              HAVERING              Havering  E05000316
# 8  KINGSTON UPON THAMES  Kingston Upon thames  E05000400
# 9               LAMBETH               Lambeth  E05000422
#
#                       ward_name                 ward_name_new  easting_m  \
# 0                   SNARESBROOK                   SNARESBROOK        NaN
# 1  CHELSFIELD AND PRATTS BOTTOM  CHELSFIELD AND PRATTS BOTTOM        NaN
# 2                 NEW ADDINGTON                 NEW ADDINGTON        NaN
# 3                     SOUTHGATE                     SOUTHGATE        NaN
# 4                GREENWICH WEST                GREENWICH WEST        NaN
# 5                    WEST GREEN                    WEST GREEN   531774.0
# 6                        HEATON                        HEATON        NaN
# 7                       MAWNEYS                       MAWNEYS        NaN
# 8                     ALEXANDRA                     ALEXANDRA        NaN
# 9                    GIPSY HILL                    GIPSY HILL   533326.0
#
#    northing_m  easting_rounded  northing_rounded     frs  \
# 0         NaN           540350            189350  London
# 1         NaN           546350            163850  London
# 2         NaN           538450            162150  London
# 3         NaN           530350            194550  London
# 4         NaN           538450            177050  London
# 5    189383.0           531750            189350  London
# 6         NaN           553450            192650  London
# 7         NaN           549750            191150  London
# 8         NaN           520450            166150  London
# 9    171168.0           533350            171150  London
#
#   incident_station_ground  first_pump_arriving_attendance_time  \
# 0             Leytonstone                                  449
# 1               Orpington                                  331
# 2               Addington                                  179
# 3               Southgate                                  264
# 4               Greenwich                                  174
# 5               Tottenham                                  327
# 6             Harold Hill                                  285
# 7                 Romford                                  269
# 8                Surbiton                                  581
# 9            West Norwood                                  232
#
#   first_pump_arriving_deployed_from_station  \
# 0                               Leytonstone
# 1                                 Orpington
# 2                                 Addington
# 3                                 Southgate
# 4                                 Greenwich
# 5                                 Tottenham
# 6                               Harold Hill
# 7                                   Romford
# 8                                  Surbiton
# 9                              West Norwood
#
#    second_pump_arriving_attendance_time  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                 335.0
# 6                                 449.0
# 7                                 386.0
# 8                                   NaN
# 9                                 247.0
#
#   second_pump_arriving_deployed_from_station  \
# 0                                       None
# 1                                       None
# 2                                       None
# 3                                       None
# 4                                       None
# 5                                    Hornsey
# 6                                    Romford
# 7                                   Hainault
# 8                                       None
# 9                               West Norwood
#
#    num_stations_with_pumps_attending  num_pumps_attending
# 0                                  1                    1
# 1                                  1                    1
# 2                                  1                    1
# 3                                  1                    1
# 4                                  1                    1
# 5                                  2                    2
# 6                                  2                    2
# 7                                  2                    2
# 8                                  1                    1
# 9                                  1                    2

# %% [markdown]
# ## How long does the fire brigade take to come to your home?

# %% [markdown]
# ## Load data from a pandas DataFrame to a new table

# %%
records = [
    {"title": "The Meaning of Life", "release_year": 1983},
    {"title": "Monty Python and the Holy Grail", "release_year": 1975},
    {"title": "Life of Brian", "release_year": 1979},
    {"title": "And Now for Something Completely Different", "release_year": 1971},
]

# Optionally set explicit indices.
# If indices are not specified, a column will be created for the default
# indices created by pandas.
index = ["Q24980", "Q25043", "Q24953", "Q16403"]
df = pandas.DataFrame(records, index=pandas.Index(index, name="wikidata_id"))

table_ref = dataset.table("monty_python")
job = client.load_table_from_dataframe(df, table_ref, location="US")

job.result()  # Waits for table load to complete.
print("Loaded dataframe to {}".format(table_ref.path))

# %% [markdown]
# ## Cleaning Up
#
# The following code deletes the dataset created for this tutorial, including all tables in the dataset.

# %%
# Retrieve the dataset from the API
dataset = client.get_dataset(client.dataset(dataset_id))

# Delete the dataset and its contents
client.delete_dataset(dataset, delete_contents=True)

print('Deleted dataset: {}'.format(dataset.path))
